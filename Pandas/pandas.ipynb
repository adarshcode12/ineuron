# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/annual-enterprise-survey-2020-financial-year-provisional-csv.csv")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# in default head takes up 5 arguments.
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
# 3  2020                     Level 1                99999       All industries
# 4  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
# in default tail takes up 5 arguments from last.
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 37075  Food product manufacturing  Percentage           H37
# 37076  Food product manufacturing  Percentage           H38
# 37077  Food product manufacturing  Percentage           H39
# 37078  Food product manufacturing  Percentage           H40
# 37079  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 37075                          Quick ratio  Financial ratios    52
# 37076  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
# so we can select the no. of rows required by using head or tail
df.head(15)
df.tail(15)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37065  2013                     Level 3                 ZZ11
# 37066  2013                     Level 3                 ZZ11
# 37067  2013                     Level 3                 ZZ11
# 37068  2013                     Level 3                 ZZ11
# 37069  2013                     Level 3                 ZZ11
# 37070  2013                     Level 3                 ZZ11
# 37071  2013                     Level 3                 ZZ11
# 37072  2013                     Level 3                 ZZ11
# 37073  2013                     Level 3                 ZZ11
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# ...

# %%
# the type of data type provided by the pandas is the DataFrame which in the form of sequential data and table.
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#store data into another csv format.
df.to_csv("Example1_csv.csv")

# %%
#so we read the csv file after converting it into the data format.
pd.read_csv("Example1_csv.csv")
# Out:
#        Unnamed: 0  Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0               0  2020                     Level 1                99999
# 1               1  2020                     Level 1                99999
# 2               2  2020                     Level 1                99999
# 3               3  2020                     Level 1                99999
# 4               4  2020                     Level 1                99999
# ...           ...   ...                         ...                  ...
# 37075       37075  2013                     Level 3                 ZZ11
# 37076       37076  2013                     Level 3                 ZZ11
# 37077       37077  2013                     Level 3                 ZZ11
# 37078       37078  2013                     Level 3                 ZZ11
# 37079       37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# ...

# %%
# read the txt file and then seperating using the sep in which ',' was provided.
df1 = pd.read_csv("/content/annual.txt" , sep=',')

# %%
# chech the data in right format
df1.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
# 3  2020                     Level 1                99999       All industries
# 4  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
# excluding the header as it may be data not column name
df2=pd.read_csv('/content/annual.txt' , sep=',' , header=None )
df2
# Out:
#           0                            1                     2  \
# 0      Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1      2020                      Level 1                 99999
# 2      2020                      Level 1                 99999
# 3      2020                      Level 1                 99999
# 4      2020                      Level 1                 99999
# ...     ...                          ...                   ...
# 37076  2013                      Level 3                  ZZ11
# 37077  2013                      Level 3                  ZZ11
# 37078  2013                      Level 3                  ZZ11
# 37079  2013                      Level 3                  ZZ11
# 37080  2013                      Level 3                  ZZ11
#
#                                 3                   4              5  \
# 0            Industry_name_NZSIOC               Units  Variable_code
# ...

# %%
# give name to a certain column
df3=pd.read_csv('/content/annual.txt' , sep=',' , header=None , names=['a','b','c','d','e','f','g','h','i'])
df3
# Out:
#                                 a                     b  \
# Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 2020                      Level 1                 99999
# 2020                      Level 1                 99999
# 2020                      Level 1                 99999
# 2020                      Level 1                 99999
# ...                           ...                   ...
# 2013                      Level 3                  ZZ11
# 2013                      Level 3                  ZZ11
# 2013                      Level 3                  ZZ11
# 2013                      Level 3                  ZZ11
# 2013                      Level 3                  ZZ11
#
#                                c                   d              e  \
# Year        Industry_name_NZSIOC               Units  Variable_code
# 2020              All industries  Dollars (millions)            H01
# 2020              All industries  Dollars (millions)            H04
# ...

# %%
# using less colums names then the columns
df3=pd.read_csv('/content/annual.txt' , sep=',' , header=None , names=['a','b','c','d','e','f','g'])
# so it take the names from back which means the front is without the names and therefore,
# if you leaves column's names then it will has that many less in the start.
df3
# Out:
#                                                                                 a  \
# Year Industry_aggregation_NZSIOC Industry_code_NZSIOC        Industry_name_NZSIOC
# 2020 Level 1                     99999                             All industries
#                                  99999                             All industries
#                                  99999                             All industries
#                                  99999                             All industries
# ...                                                                           ...
# 2013 Level 3                     ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
# ...

# %%
# skip some of the rows.
pd.read_csv('/content/annual.txt',sep=',',skiprows=[1,2,3,4])
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37071  2013                     Level 3                 ZZ11
# 37072  2013                     Level 3                 ZZ11
# 37073  2013                     Level 3                 ZZ11
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H08
# 1                  All industries  Dollars (millions)           H09
# ...

# %%
#change the value to NaN which is Null during the read. (changed the value to NaN)
pd.read_csv('/content/annual.txt',sep=',',skiprows=[1,2,3,4],na_values=['99999'])
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                  NaN
# 1      2020                     Level 1                  NaN
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37071  2013                     Level 3                 ZZ11
# 37072  2013                     Level 3                 ZZ11
# 37073  2013                     Level 3                 ZZ11
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H08
# 1                  All industries  Dollars (millions)           H09
# ...

# %%
# data types of all the columns.
df=pd.read_csv('/content/annual.txt',sep=',')
# the data type of the df.dtypes is dhownin series format.
df.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
# describe the different element in tables. 
df.describe()
# it only give data for the numerical data but if required can be altered.
# 25% means arrang in ascending order and then 25th position element.
# Out:
#                Year
# count  37080.000000
# mean    2016.500000
# std        2.291319
# min     2013.000000
# 25%     2014.750000
# 50%     2016.500000
# 75%     2018.250000
# max     2020.000000

# %%
# STORE DATA 


# remove the index from the table every time we convert to csv (using index)
df.to_csv('result.csv',sep='#',index=False)

# %%
# only store the column mentioned or required.
df.to_csv('result.csv',sep='#',columns=['Year','Industry_aggregation_NZSIOC'],index=False)

# %%
# only showing the data with year and aggregation
df5=pd.read_csv('result.csv',sep='#')

# %%
# in columns it only show colums names and their data types
df5.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC'], dtype='object')

# %%
# we can view each column in this format
df5['Year']
# the data type of this format is Series which is somewhat related to the list which contains different types in it.
type(df5['Year'])
# Out:
# pandas.core.series.Series

# %%
df5['Year']  # Series
df5[['Year']] #DataFrame
# Out:
#        Year
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
# ...     ...
# 37075  2013
# 37076  2013
# 37077  2013
# 37078  2013
# 37079  2013
#
# [37080 rows x 1 columns]

# %%
# read from excel 

#in default it take up only the first sheet in the excel
ex1=pd.read_excel('SampleData.xlsx')
ex1
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                            Online Instruction Page
# 4          NaN        NaN                              Sample Data for Excel
# 5          NaN        NaN                           Office Supply Sales Data
# 6          NaN        NaN                                                NaN
# 7          NaN        NaN                                  Related tutorials
# 8          NaN        NaN                            More Excel Sample Files
# 9          NaN        NaN                                 Named Excel Tables
# 10         NaN        NaN                                    Data Entry Tips
# ...

# %%
# take another sheet in the excel
ex2=pd.read_excel('/content/SampleData.xlsx',sheet_name='SalesOrders')
ex2
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2021-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2021-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2021-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2021-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2021-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2021-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2021-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2021-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2021-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2021-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2021-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2021-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2021-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
ex2['Region']
# Out:
# 0        East
# 1     Central
# 2     Central
# 3     Central
# 4        West
# 5        East
# 6     Central
# 7     Central
# 8        West
# 9        East
# 10    Central
# 11       East
# 12       East
# 13       East
# 14    Central
# 15       East
# 16    Central
# 17       East
# 18       East
# 19    Central
# 20    Central
# 21       East
# 22    Central
# 23    Central
# 24       East
# 25       West
# 26    Central
# 27    Central
# 28       East
# 29    Central
# 30    Central
# 31    Central
# 32       East
# 33    Central
# 34    Central
# 35       West
# 36    Central
# 37       West
# 38       West
# 39    Central
# 40    Central
# 41    Central
# 42    Central
# Name: Region, dtype: object

# %%
#read from HTML file
ht1=pd.read_html('https://www.icc-cricket.com/rankings/mens/player-rankings/test')
print(type(ht1)) 
# it is form of a list as it contains more table in a single list 
ht1
# Out:
# <class 'list'>
# [       Pos              Player Team  Rating
#  0   2  (0)  Marnus Labuschagne  AUS     892
#  1   3  (0)         Steve Smith  AUS     845
#  2   4  (0)          Babar Azam  PAK     815
#  3   5  (0)     Kane Williamson   NZ     798
#  4   6  (0)  Dimuth Karunaratne   SL     772
#  5   7  (0)       Usman Khawaja  AUS     757
#  6   8  (0)        Rohit Sharma  IND     754
#  7   9  (0)         Travis Head  AUS     744
#  8  10  (0)         Virat Kohli  IND     742,
#                                                   Pos               Player  \
#  0                                             2  (0)  Ravichandran Ashwin
#  1                                             3  (0)       Jasprit Bumrah
#  2                                             4  (0)       Shaheen Afridi
#  3                                             5  (0)        Kagiso Rabada
#  4                                             6  (0)        Kyle Jamieson
# ...

# %%
#view a particular table in the list
ht1[1] # we view the 1st table
# Out:
#                                                  Pos               Player  \
# 0                                             2  (0)  Ravichandran Ashwin
# 1                                             3  (0)       Jasprit Bumrah
# 2                                             4  (0)       Shaheen Afridi
# 3                                             5  (0)        Kagiso Rabada
# 4                                             6  (0)        Kyle Jamieson
# 5                                             7  (0)       James Anderson
# 6  8  This player has moved up in the rankings si...          Kemar Roach
# 7  9  (1)  This player has moved down in the rank...          Neil Wagner
# 8  10  (1)  This player has moved down in the ran...          Trent Boult
#
#   Team  Rating
# 0  IND     850
# 1  IND     830
# 2  PAK     827
# 3   SA     818
# 4   NZ     796
# 5  ENG     795
# 6   WI     769
# 7   NZ     762
# 8   NZ     753

# %%
# view the json file

import json

s='''{
  "name":"adarsh",
  "camp":["iNeuron","Coresera","GeeksforGeeks"]
} '''

js1=json.loads(s)
js1
# Out:
# {'camp': ['iNeuron', 'Coresera', 'GeeksforGeeks'], 'name': 'adarsh'}

# %%
# for each element in the array we make name for each element
pd.DataFrame(js1)
# Out:
#      name           camp
# 0  adarsh        iNeuron
# 1  adarsh       Coresera
# 2  adarsh  GeeksforGeeks

# %%
#only show camp or selected column

pd.DataFrame(js1,columns=['camp'])
# Out:
#             camp
# 0        iNeuron
# 1       Coresera
# 2  GeeksforGeeks

# %%
# !pip install requests
# rake request  from API in JSON and filter it.
import requests
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# response 200 means we get some data as request fro api
res
# Out:
# <Response [200]>

# %%
js=res.json()
js[1]['title']
# Out:
# 'BUG: using read_xml with iterparse and names will ignore duplicate values'

# %%
# see all the titles in each list in the dictionary

for i in range(len(js)):
  print(js[i]['title'])
# Out:
# QST:  How to write non-optional fields in Parquet files with Pandas?
# BUG: using read_xml with iterparse and names will ignore duplicate values
# CI: Run all code checks even if one fails
# BUG: Fix issues with numeric_only deprecation
# BUG: DataFrame.replace fails to replace value when column contains pd.NA
# Revert "Backport PR #47318 on branch 1.4.x (CI: Pin PYTEST_WORKERS=1 for Windows builds due to memory errors)"
# BUG: TypeError: Int64 when using `pd.pivot_table` with `Int64` values
# REGR: maybe_convert_objects ignoring uints
# BUG: to_sql with method=callable not returning int raising TypeError
# DOC: Start v1.4.4 release notes
# BUG: Timestamp.tz_localize inconsistent with pydatetime behavior
# BUG: GH33912 fixed issue with precision of the the left end
# ENH/TST: Add BaseInterfaceTests tests for ArrowExtensionArray PT2
# DEPS/TST: tzdata is optional, not required
# Fix signature of initObjToJSON
# BUG: `pd.period_range` ignores multiple of `start` frequency
# ...

# %%
# same process with pandas with dataframe
pd.DataFrame(js,columns=['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# to_pickle --> convert into seralization process(object into byte format)

df3.to_pickle("my_pickle")  # convert the df3DataFrame into byte form

# %%
# HDFStore which is used to directly into serilized 

h5_data = pd.HDFStore('test.h5')
h5_data
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: test.h5

# %%
# this has the Series data types.
ex2.dtypes == 'object'
ex2
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2021-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2021-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2021-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2021-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2021-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2021-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2021-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2021-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2021-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2021-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2021-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2021-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2021-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
df6=df3.dtypes[df3.dtypes=='object']
df6  # it is in form of the Series
# Out:
# pandas.core.series.Series

# %%
df7=df3.dtypes[df3.dtypes=='object'].index
df7   # it is in form of a list which contains columns name and data types.
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')

# %%
# converting the list into the DataFrame
df8 = df3[df3.dtypes[df3.dtypes == 'object'].index]
df8
# Out:
#                                                                                 a  \
# Year Industry_aggregation_NZSIOC Industry_code_NZSIOC        Industry_name_NZSIOC
# 2020 Level 1                     99999                             All industries
#                                  99999                             All industries
#                                  99999                             All industries
#                                  99999                             All industries
# ...                                                                           ...
# 2013 Level 3                     ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
# ...

# %%
# different description for a cartageroical data.
df8.describe()
# Out:
#                                                    a                   b  \
# count                                          37081               37081
# unique                                           120                   4
# top     Public Order, Safety and Regulatory Services  Dollars (millions)
# freq                                             682               29152
#
#             c                             d                      e      f  \
# count   37081                         37081                  37081  37081
# unique     40                            42                      4   9296
# top       H40  Total equity and liabilities  Financial performance      C
# freq     1112                          1112                  18536   1745
#
#                           g
# count                 37081
# unique                  122
# top     ANZSIC06 group C170
# freq                    576

# %%
# with the help of the DataFrame vire only certain columns
df3[['b','c']]
# Out:
#                                                                         b  \
# Year Industry_aggregation_NZSIOC Industry_code_NZSIOC               Units
# 2020 Level 1                     99999                 Dollars (millions)
#                                  99999                 Dollars (millions)
#                                  99999                 Dollars (millions)
#                                  99999                 Dollars (millions)
# ...                                                                   ...
# 2013 Level 3                     ZZ11                          Percentage
#                                  ZZ11                          Percentage
#                                  ZZ11                          Percentage
#                                  ZZ11                          Percentage
#                                  ZZ11                          Percentage
#
#                                                                    c
# ...

# %%
# slice in the list of the data
df3['c'][2:10]
# Out:
# 2020  Level 1  99999    H04
#                99999    H05
#                99999    H07
#                99999    H08
#                99999    H09
#                99999    H10
#                99999    H11
#                99999    H12
# Name: c, dtype: object

# %%
# it show data of each columns.
for i in df3.columns:
  print(df3[i])
# Out:
# Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC          Industry_name_NZSIOC
# 2020  Level 1                      99999                               All industries
#                                    99999                               All industries
#                                    99999                               All industries
#                                    99999                               All industries
#                                                                       ...
# 2013  Level 3                      ZZ11                    Food product manufacturing
#                                    ZZ11                    Food product manufacturing
#                                    ZZ11                    Food product manufacturing
#                                    ZZ11                    Food product manufacturing
#                                    ZZ11                    Food product manufacturing
# Name: a, Length: 37081, dtype: object
# ...

# %%
# add columns in the DataFrame with each rows having value kumar

df3["adarsh"]='kumar'

# %%
df3
# Out:
#                                                                                 a  \
# Year Industry_aggregation_NZSIOC Industry_code_NZSIOC        Industry_name_NZSIOC
# 2020 Level 1                     99999                             All industries
#                                  99999                             All industries
#                                  99999                             All industries
#                                  99999                             All industries
# ...                                                                           ...
# 2013 Level 3                     ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
# ...

# %%
# each rows have same value as c in the new column of adarsh by overriding it.

df3['adarsh']=df3['c']

# %%
df3
# Out:
#                                                                                 a  \
# Year Industry_aggregation_NZSIOC Industry_code_NZSIOC        Industry_name_NZSIOC
# 2020 Level 1                     99999                             All industries
#                                  99999                             All industries
#                                  99999                             All industries
#                                  99999                             All industries
# ...                                                                           ...
# 2013 Level 3                     ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
#                                  ZZ11                  Food product manufacturing
# ...

# %%
# categorised the data

ca1=pd.Categorical(df3['c'])
ca1
# Out:
# ['Variable_code', 'H01', 'H04', 'H05', 'H07', ..., 'H37', 'H38', 'H39', 'H40', 'H41']
# Length: 37081
# Categories (40, object): ['H01', 'H02', 'H03', 'H04', ..., 'H39', 'H40', 'H41', 'Variable_code']

# %%
# unique data for a column
df3['c'].unique()
# Out:
# array(['Variable_code', 'H01', 'H04', 'H05', 'H07', 'H08', 'H09', 'H10',
#        'H11', 'H12', 'H13', 'H14', 'H19', 'H20', 'H21', 'H22', 'H23',
#        'H24', 'H25', 'H26', 'H29', 'H30', 'H31', 'H32', 'H33', 'H34',
#        'H35', 'H36', 'H37', 'H39', 'H40', 'H41', 'H06', 'H27', 'H28',
#        'H02', 'H03', 'H17', 'H18', 'H38'], dtype=object)

# %%
# any data is Null

df3['c'].isnull()
# Out:
# Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC    False
# 2020  Level 1                      99999                   False
#                                    99999                   False
#                                    99999                   False
#                                    99999                   False
#                                                            ...
# 2013  Level 3                      ZZ11                    False
#                                    ZZ11                    False
#                                    ZZ11                    False
#                                    ZZ11                    False
#                                    ZZ11                    False
# Name: c, Length: 37081, dtype: bool

# %%
# only show data with null in the rows

ser=df3['c'][df3['c'].isnull()==True]
ser  # as there is no object with null value
# Out:
# Series([], Name: c, dtype: object)

# %%
# for row manipulation
# it provide data for the null value and show data in table form

df3.iloc[ser.index]
# Out:
# Empty DataFrame
# Columns: [a, b, c, d, e, f, g, adarsh]
# Index: []

# %%
# show data with largest value of c

df3=pd.read_csv('/content/annual.txt' , sep=',')
df3
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df3['Variable_category'][df3['Value']==max(df3['Value'])]
# Out:
# 3469     Financial position
# 3470     Financial position
# 8104     Financial position
# 8105     Financial position
# 12739    Financial position
# 12740    Financial position
# 17442    Financial position
# 17443    Financial position
# 22077    Financial position
# 22078    Financial position
# 26280    Financial position
# 26282    Financial position
# 26314    Financial position
# 26316    Financial position
# 26382    Financial position
# 26384    Financial position
# 26712    Financial position
# 26713    Financial position
# 35982    Financial position
# 35983    Financial position
# Name: Variable_category, dtype: object

# %%
# add new column into the new column

df3['variable_category_code'] = df3['Variable_category']+df3['Variable_code']

# %%
df3
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...
